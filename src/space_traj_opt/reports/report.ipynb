# %%
from space_traj_opt.postprocessing.data_client import CSVClient
from space_traj_opt.postprocessing.template_plotter import TemplatePlotter
from space_traj_opt.reports.orbit_plot import OrbitPlot

# %%
clients = [CSVClient("traj_opt_sol")]

# %%
TemplatePlotter("plot_report_3d", clients).plot()

# %%
orbit = OrbitPlot()
orbit.add_trace()
orbit.show()
